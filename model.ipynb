# %%
import os
import sys
import argparse
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import TensorDataset, DataLoader
import random
from torch.utils import data


data = pd.read_csv("outputfile.csv") 
ids = [x for x in range(1, len(data)+1)]
data.insert(0, 'IDs', ids)

X = data.iloc[:, 3:-1]
y = data["Authors"]
train = X.values
labels = y.values

X = torch.from_numpy(train).float()
y = torch.from_numpy(labels).float()

train_data = TensorDataset(X, y)
train_loader = DataLoader(dataset=train_data, batch_size=1, shuffle=True)

# %%
class DocPredict(nn.Module):
    def __init__(self, input_size, num_classes):
        super().__init__()      
        self.linear = nn.Linear(input_size, num_classes)

        # activation function
        self.sigmoid = nn.Sigmoid()


    def forward(self, x):
        m = self.linear(x)
        o = self.sigmoid(m)
        
        return o
    

class DocFFNN():
    def __init__(self, documents, epochs=3, lr=0.01):
        super().__init__(doc)
        self.epochs = epochs
        self.lr = lr
    
    def make_model(self):
        self.model = DocPredict(len(train_loader),13)

    
    def sample(self, n):
        samples = []
        c = 1
        for i in range(n):
            self.doc1 = random.choice(range(len(self)))
            self.doc2 = random.choice(range(len(self)))
            
        return self.doc1, self.doc2
    
    print(sample(train_loader,2))
    
    def eval(self):
        self.model.eval()

    
    def train(self, docs):
        """
        The training loop.
        """
        criterion = nn.CrossEntropyLoss()
       # optimizer = optim.SGD(self.model.parameters(), lr=self.lr)
        for z in range(self.epochs):
            print("Running epoch {}...".format(z))
            for i in range(len(docs)):
                instance = torch.Tensor([docs[i],docs[i+1]])
                label = torch.LongTensor([self.features.index(inputs[1][i])])
                         
                output = self.model(instance)

                loss = criterion(output, label)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
net = DocPredict(len(train_loader),2)
print(net)

print(list(net.parameters()))
# Out:
# (2870, 2837)
# DocPredict(
#   (linear): Linear(in_features=2929, out_features=2, bias=True)
#   (sigmoid): Sigmoid()
# )
# [Parameter containing:
# tensor([[ 0.0094, -0.0141,  0.0059,  ..., -0.0172, -0.0024,  0.0065],
#         [ 0.0180,  0.0130, -0.0126,  ...,  0.0073,  0.0175, -0.0107]],
#        requires_grad=True), Parameter containing:
# tensor([0.0037, 0.0084], requires_grad=True)]
